# %%
# fetch NASA data
from src.client.api_client import fetch_neo_data
data = fetch_neo_data()

# %%
# store raw data in S3
from src.db.aws_client import AWSClient
aws_client = AWSClient()
aws_client.save_data_to_s3(data)
# Out:
# [WARNING] 2026-01-01 20:56:21 - Uploading data to s3://nasa-neo-pipeline/raw-neo/2026-01-01.json
# [INFO] 2026-01-01 20:56:24 - Successfully uploaded data to AWS S3: s3://nasa-neo-pipeline/raw-neo/2026-01-01.json

# %%
# transform and clean data for storage
from src.transform.flatten_neo import extract_neo
flat_data = extract_neo(data)
# Out:
# [INFO] 2026-01-01 20:56:25 - Successfully flattened NEO data, except for close approach data.

# %%
# create a separate list for close approaches
from src.transform.clean_approaches import get_new_neo_approaches

neo, approaches = get_new_neo_approaches(flat_data)

# %%
# store both neo data and approaches data in pandas dataframes
import pandas as pd
neo_df = pd.DataFrame(neo["neo"])
approaches_df = pd.DataFrame(approaches)

# %%
neo_df.head()
# Out:
#    reference_id            neo_name  \
# 0       2259221  259221 (2003 BA21)
# 1       3022973         (1999 TN13)
# 2       3837745          (2019 AR7)
# 3      54215203           (2021 VF)
# 4      54297798          (2022 QN5)
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.19
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.60
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 26.70
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 27.85
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 25.83
#
#    estimated_diameter_min_km  estimated_diameter_max_km  \
# 0                   0.385971                   0.863058
# 1                   0.050647                   0.113250
# 2                   0.012149                   0.027167
# 3                   0.007154                   0.015997
# 4                   0.018137                   0.040555
#
#    is_potentially_hazardous  is_sentry_object
# 0                     False             False
# 1                     False             False
# 2                     False             False
# 3                     False             False
# 4                     False             False

# %%
approaches_df.head()
# Out:
#    reference_id  close_approach_date_epoch  relative_velocity_kms  \
# 0       2259221              1767846240000              26.110554
# 1       3022973              1767889320000              15.487924
# 2       3837745              1767876420000              16.878495
# 3      54215203              1767911460000               7.892092
# 4      54297798              1767879000000              20.944791
#
#    miss_distance_km orbiting_body
# 0      2.973812e+07         Earth
# 1      4.295819e+07         Earth
# 2      6.766750e+07         Earth
# 3      3.514553e+07         Earth
# 4      3.621900e+07         Earth

# %%
# standardize NEO names to a format: "YYYY identifier"
import re

regex = r"\d{4} [\w\d]+"
neo_df["clean_neo_name"] = neo_df["neo_name"].apply(
  lambda name: (
    re.search(regex, name).group()  # type: ignore
    if re.search(regex, name) is not None 
    else name
  )
)

neo_df.insert(2, "clean_neo_name", neo_df.pop("clean_neo_name"))
neo_df.head()
# Out:
#    reference_id            neo_name clean_neo_name  \
# 0       2259221  259221 (2003 BA21)      2003 BA21
# 1       3022973         (1999 TN13)      1999 TN13
# 2       3837745          (2019 AR7)       2019 AR7
# 3      54215203           (2021 VF)        2021 VF
# 4      54297798          (2022 QN5)       2022 QN5
#
#                                         nasa_jpl_url  absolute_magnitude_h  \
# 0  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 19.19
# 1  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 23.60
# 2  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 26.70
# 3  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                 27.85
# 4  https://ssd.jpl.nasa.gov/tools/sbdb_lookup.htm...                